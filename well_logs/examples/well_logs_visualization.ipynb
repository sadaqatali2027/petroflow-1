# %% [markdown]
# # Визуализация каротажей

# %%
import os
import sys
sys.path.append(os.path.join("..", ".."))

from well_logs import WellLogsDataset

# %%
WELL_NPZ_PATH = "/home/alexander/Documents/Data/Крайнее ГИС РИГИС/npz/*.npz"
ds = WellLogsDataset(path=WELL_NPZ_PATH, sort=True)

# %%
batch = ds.next_batch(1).load(fmt="npz", components=["dept", "logs"]).drop_nans()

# %%
batch._show_logs(start=2500, end=2700)
