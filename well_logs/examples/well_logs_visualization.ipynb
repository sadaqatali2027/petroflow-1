# %% [markdown]
# # Визуализация каротажей

# %%
import os
import sys
sys.path.append(os.path.join("..", ".."))

from well_logs import WellLogsDataset

# %%
WELL_NPZ_PATH = "/notebooks/data/geolog/npz/*.npz"
ds = WellLogsDataset(path=WELL_NPZ_PATH, sort=True)

# %%
batch = ds.next_batch(50).load(fmt="npz").drop_nans()

# %%
import numpy as np

a = np.array([batch.logs[i].mean(axis=1) for i in range(len(batch.indices))])
a.std(axis=0) / a.mean(axis=0)
# Out:
# array([0.15805984, 0.18691798, 4.3093819 , 0.18509758, 0.18429382,
#        0.17074386, 0.1542399 , 0.17988664, 0.2779742 , 0.18511933,
#        0.14419149, 0.40551044])

# %%
a.shape
# Out:
# (54, 12)

# %%
batch.show_logs(start=2600, plot_mask=True)
