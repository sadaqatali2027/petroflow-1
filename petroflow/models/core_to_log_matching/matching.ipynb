# %% [markdown]
# # Core-to-log matching

# %% [markdown]
# ## Contents

# %% [markdown]
# * [Problem description](#Problem-description)
# * [Well matching](#Well-matching)
# * [Dataset matching](#Dataset-matching)
# * [Matching research](#Matching-research)
# * [Conclusion](#Conclusion)

# %% [markdown]
# ## Problem description

# %% [markdown]
# Perform core-to-log matching by shifting core samples in order to maximize correlation between well and core logs.

# %% [markdown]
# Shifted core samples must satisfy the following constraints:
# * Boring intervals constraints:
#     * boring intervals must be shifted by no more than 10 meters
#     * boring intervals must not overlap
#     * the order of boring intervals must remain unchanged
#     * if several boring intervals are extracted one after another, they must be shifted by the same delta
# * Lithology intervals constraints (if defined for a well):
#     * lithology intervals can be moved only inside the corresponding boring interval
#     * lithology intervals must not overlap
#     * the order of lithology intervals must remain unchanged

# %%
import os
import sys

sys.path.insert(0, os.path.join("..", "..", ".."))
from petroflow import Well, WellDataset
from petroflow.batchflow import Pipeline, C, L
from petroflow.batchflow.research import Research, Option

# %% [markdown]
# The following matching mode precedence (from highest to lowest) is used in all experiments. Each mode is specified as follows:
#
# `<well_log> ~ <sign><core_attr>.<core_log>`, where:
# * `well_log` - mnemonic of a well log to use
# * `sign` - a sign of the theoretical correlation between well and core data
# * `core_attr` - an attribute of a well to get core data from
# * `core_log` - mnemonic of a core log or property to use

# %%
MATCHING_MODES = [
    "GK ~ +core_logs.GK",
    "GGKP ~ +core_logs.DENSITY",
    "GGKP ~ -core_properties.POROSITY",
    "GK ~ -core_properties.POROSITY",
]

# %% [markdown]
# ## Well matching

# %% [markdown]
# If you need to process only a single well, specify the path to it and create a `Well` instance:

# %%
WELL_PATH = "/path/to/a/well/"
well = Well(path=WELL_PATH)

# %% [markdown]
# First, let's visualize how much the well and core data are shifted relative to each other. Since the matching is not performed yet, you need to explicitly specify which core and well logs you want to compare. In this case, we will take a look at gamma ray logs:

# %%
well.plot_matching(mode="GK ~ +core_logs.GK")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="07d2d447-d58d-40c7-a61f-206fb78032a0" class="plotly-graph-div" style="height:700px; width:920px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("07d2d447-d58d-40c7-a61f-206fb78032a0")) {
#                     Plotly.newPlot(
#                         '07d2d447-d58d-40c7-a61f-206fb78032a0',
#                         [{"line": {"color": "rgb(255, 127, 14)"}, "name": "Well GK", "showlegend": false, "type": "scatter", "x": [4.886, 4.858, 4.773, 4.73, 4.672, 4.606, 4.784, 4.945, 5.089, 5.157, 5.123, 4.964, 4.983, 4.886, 4.596, 4.418, 4.203, 3.893, 4.092, 4.41, 4.756, 5.57, 6.505, 7.406, 8.458, 9.448, 10.009, 10.262, 10.359, 10.391, 10.234, 9.978, 9.778, 9.435, 9.022, 9.052, 9.094, 9.146, 9.225, 9.189, 9.035, 9.142, 9.143, 8.999, 9.02, 9.028, 8.993, 9.354, 9.637, 9.668, 9.473, 9.149, 8.639, 8.47, 8.394, 8.305, 8.489, 8.744, 8.882, 9.01, 9.116, 9.144, 9.014, 8.782, 8.449, 8.117, 7.801, 7.746, 7.75, 7.811, 8.198, 8.594, 9.0, 9.227, 9.316, 9.239, 8.826, 8.601, 8.711, 8.909, 9.032, 8.991, 9.12, 9.234, 9.226, 9.813, 10.374, 10.319, 10.031, 9.584, 8.856, 8.58, 8.5, 8.287, 8.089, 7.9, 7.702, 7.67, 7.766, 7.991, 7.978, 7.757, 7.538, 7.295, 7.026, 7.153, 7.417, 7.836, 8.468, 9.073, 9.601, 9.569, 9.335, 8.881, 8.501, 8.329, 8.614, 8.493, 8.211, 7.812, 7.167, 6.502, 6.147, 5.778, 5.399, 5.007, 4.854, 4.84, 4.778, 4.755, 4.753, 4.598, 4.593, 4.721, 4.777, 4.906, 5.116, 5.087, 5.144, 5.329, 5.266, 5.269, 5.419, 5.448, 5.476, 5.542, 5.385, 5.196, 5.059, 5.153, 5.31, 5.439, 5.681], "xaxis": "x", "y": [2269.5, 2269.6, 2269.7, 2269.8, 2269.9, 2270.0, 2270.1, 2270.2, 2270.3, 2270.4, 2270.5, 2270.6, 2270.7, 2270.8, 2270.9, 2271.0, 2271.1, 2271.2, 2271.3, 2271.4, 2271.5, 2271.6, 2271.7, 2271.8, 2271.9, 2272.0, 2272.1, 2272.2, 2272.3, 2272.4, 2272.5, 2272.6, 2272.7, 2272.8, 2272.9, 2273.0, 2273.1, 2273.2, 2273.3, 2273.4, 2273.5, 2273.6, 2273.7, 2273.8, 2273.9, 2274.0, 2274.1, 2274.2, 2274.3, 2274.4, 2274.5, 2274.6, 2274.7, 2274.8, 2274.9, 2275.0, 2275.1, 2275.2, 2275.3, 2275.4, 2275.5, 2275.6, 2275.7, 2275.8, 2275.9, 2276.0, 2276.1, 2276.2, 2276.3, 2276.4, 2276.5, 2276.6, 2276.7, 2276.8, 2276.9, 2277.0, 2277.1, 2277.2, 2277.3, 2277.4, 2277.5, 2277.6, 2277.7, 2277.8, 2277.9, 2278.0, 2278.1, 2278.2, 2278.3, 2278.4, 2278.5, 2278.6, 2278.7, 2278.8, 2278.9, 2279.0, 2279.1, 2279.2, 2279.3, 2279.4, 2279.5, 2279.6, 2279.7, 2279.8, 2279.9, 2280.0, 2280.1, 2280.2, 2280.3, 2280.4, 2280.5, 2280.6, 2280.7, 2280.8, 2280.9, 2281.0, 2281.1, 2281.2, 2281.3, 2281.4, 2281.5, 2281.6, 2281.7, 2281.8, 2281.9, 2282.0, 2282.1, 2282.2, 2282.3, 2282.4, 2282.5, 2282.6, 2282.7, 2282.8, 2282.9, 2283.0, 2283.1, 2283.2, 2283.3, 2283.4, 2283.5, 2283.6, 2283.7, 2283.8, 2283.9, 2284.0, 2284.1, 2284.2, 2284.3, 2284.4, 2284.5, 2284.6, 2284.7], "yaxis": "y"}, {"line": {"color": "rgb(31, 119, 180)"}, "name": "Core GK", "showlegend": false, "type": "scatter", "x": [7.94899988174438, 9.88399982452393, 10.0920000076294, 10.5329999923706, 10.289999961853, 8.60000038146973, 8.49199962615967, 7.93599987030029, 9.93900012969971, 10.7679996490479, 8.449999809265138, 9.16699981689453, 9.98900032043457, 10.7250003814697, 10.2110004425049, 11.0600004196167, 9.6540002822876, 9.51700019836426, 8.199999809265138, 8.68400001525879, 8.88099956512451, 3.6970000267028795, 3.4289999008178698, 2.09999990463257, 1.65400004386902, 2.2000000476837203, 2.37899994850159, 2.45300006866455, 3.9479999542236297, 4.848999977111821, 6.300000190734861, 8.25500011444092, 12.6680002212524, 12.529999732971199, 9.69400024414063, 6.67799997329712, 9.14299964904785, 10.067999839782699, 10.5240001678467, 11.697999954223599, 8.35000038146973, 8.60400009155273, 9.73200035095215, 10.4829998016357, 9.170000076293949], "xaxis": "x", "y": [2272.6, 2272.8, 2273.0, 2273.2, 2273.4, 2273.6, 2273.8, 2274.0, 2274.2, 2274.4, 2274.6, 2274.8, 2275.0, 2275.2, 2275.4, 2275.6, 2275.8, 2276.0, 2276.2, 2276.4, 2276.6, 2276.9, 2277.1, 2277.3, 2277.5, 2277.7, 2277.9, 2278.1, 2278.3, 2278.5, 2278.7, 2278.9, 2279.1, 2279.3, 2279.5, 2279.7, 2279.9, 2280.1, 2280.3, 2280.5, 2280.7, 2280.9, 2281.1, 2281.3, 2281.5], "yaxis": "y"}, {"line": {"color": "rgb(255, 127, 14)"}, "name": "Well GK", "showlegend": false, "type": "scatter", "x": [5.822, 5.583, 5.649, 5.712, 5.449, 5.643, 5.962, 6.007, 6.204, 6.438, 6.415, 6.623, 7.013, 7.8, 8.926, 10.301,  ...

# %% [markdown]
# The figure shows that coring intervals must be shifted down for about two meters to perfectly match the well data. Now let's run the matching procedure and look at how the well will change:

# %%
well = well.check_regularity().match_core_logs(mode=MATCHING_MODES)
well.plot_matching()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="cb6f5ff3-a900-41ae-bdf8-827c50013abb" class="plotly-graph-div" style="height:700px; width:520px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cb6f5ff3-a900-41ae-bdf8-827c50013abb")) {
#                     Plotly.newPlot(
#                         'cb6f5ff3-a900-41ae-bdf8-827c50013abb',
#                         [{"line": {"color": "rgb(255, 127, 14)"}, "name": "Well GK", "showlegend": false, "type": "scatter", "x": [8.775, 8.582, 8.306, 8.14, 8.109, 8.499, 8.741, 8.877, 8.829, 8.671, 8.442, 8.258, 8.202, 8.249, 8.282, 8.551, 9.051, 9.099, 9.226, 9.459, 9.121, 8.921, 8.978, 8.985, 8.973, 8.94, 9.003, 9.042, 8.987, 8.975, 8.939, 8.801, 8.747, 8.776, 8.997, 8.943, 8.785, 8.711, 8.513, 8.286, 8.328, 8.42, 8.523, 8.334, 8.204, 8.116, 7.78, 7.702, 7.879, 8.116, 8.411, 8.777, 8.741, 8.526, 8.092, 7.875, 7.738, 7.694, 7.76, 7.897, 8.14, 8.349, 8.508, 8.552, 8.042, 7.386, 6.909, 6.328, 5.746, 5.412, 5.094, 4.826, 4.886, 4.858, 4.773, 4.73, 4.672, 4.606, 4.784, 4.945, 5.089, 5.157, 5.123, 4.964, 4.983, 4.886, 4.596, 4.418, 4.203, 3.893, 4.092, 4.41, 4.756, 5.57, 6.505, 7.406, 8.458, 9.448, 10.009, 10.262, 10.359, 10.391, 10.234, 9.978, 9.778, 9.435, 9.022, 9.052, 9.094, 9.146, 9.225, 9.189, 9.035, 9.142, 9.143, 8.999, 9.02, 9.028, 8.993, 9.354, 9.637, 9.668, 9.473, 9.149, 8.639, 8.47, 8.394, 8.305, 8.489, 8.744, 8.882, 9.01, 9.116, 9.144, 9.014, 8.782, 8.449, 8.117, 7.801, 7.746, 7.75, 7.811, 8.198, 8.594, 9.0, 9.227, 9.316, 9.239, 8.826, 8.601, 8.711, 8.909], "xaxis": "x", "y": [2262.3, 2262.4, 2262.5, 2262.6, 2262.7, 2262.8, 2262.9, 2263.0, 2263.1, 2263.2, 2263.3, 2263.4, 2263.5, 2263.6, 2263.7, 2263.8, 2263.9, 2264.0, 2264.1, 2264.2, 2264.3, 2264.4, 2264.5, 2264.6, 2264.7, 2264.8, 2264.9, 2265.0, 2265.1, 2265.2, 2265.3, 2265.4, 2265.5, 2265.6, 2265.7, 2265.8, 2265.9, 2266.0, 2266.1, 2266.2, 2266.3, 2266.4, 2266.5, 2266.6, 2266.7, 2266.8, 2266.9, 2267.0, 2267.1, 2267.2, 2267.3, 2267.4, 2267.5, 2267.6, 2267.7, 2267.8, 2267.9, 2268.0, 2268.1, 2268.2, 2268.3, 2268.4, 2268.5, 2268.6, 2268.7, 2268.8, 2268.9, 2269.0, 2269.1, 2269.2, 2269.3, 2269.4, 2269.5, 2269.6, 2269.7, 2269.8, 2269.9, 2270.0, 2270.1, 2270.2, 2270.3, 2270.4, 2270.5, 2270.6, 2270.7, 2270.8, 2270.9, 2271.0, 2271.1, 2271.2, 2271.3, 2271.4, 2271.5, 2271.6, 2271.7, 2271.8, 2271.9, 2272.0, 2272.1, 2272.2, 2272.3, 2272.4, 2272.5, 2272.6, 2272.7, 2272.8, 2272.9, 2273.0, 2273.1, 2273.2, 2273.3, 2273.4, 2273.5, 2273.6, 2273.7, 2273.8, 2273.9, 2274.0, 2274.1, 2274.2, 2274.3, 2274.4, 2274.5, 2274.6, 2274.7, 2274.8, 2274.9, 2275.0, 2275.1, 2275.2, 2275.3, 2275.4, 2275.5, 2275.6, 2275.7, 2275.8, 2275.9, 2276.0, 2276.1, 2276.2, 2276.3, 2276.4, 2276.5, 2276.6, 2276.7, 2276.8, 2276.9, 2277.0, 2277.1, 2277.2, 2277.3, 2277.4], "yaxis": "y"}, {"line": {"color": "rgb(31, 119, 180)"}, "name": "Core GK", "showlegend": false, "type": "scatter", "x": [7.94899988174438, 9.88399982452393, 10.0920000076294, 10.5329999923706, 10.289999961853, 8.60000038146973, 8.49199962615967, 7.93599987030029, 9.93900012969971, 10.7679996490479, 8.449999809265138, 9.16699981689453, 9.98900032043457, 10.7250003814697, 10.2110004425049, 11.0600004196167, 9.6540002822876, 9.51700019836426, 8.199999809265138, 8.68400001525879, 8.88099956512451, 3.6970000267028795, 3.4289999008178698, 2.09999990463257, 1.65400004386902, 2.2000000476837203, 2.37899994850159, 2.45300006866455, 3.9479999542236297, 4.848999977111821, 6.300000190734861, 8.25500011444092, 12.6680002212524, 12.529999732971199, 9.69400024414063, 6.67799997329712, 9.14299964904785, 10.067999839782699, 10.5240001678467, 11.697999954223599, 8.35000038146973, 8.60400009155273, 9.73200035095215, 10.4829998016357, 9.170000076293949], "xaxis": "x", "y": [2265.36, 2265.56, 2265.76, 2265.96, 2266.16, 2266.36, 2266.56, 2266.76, 2266.96, 2267.16, 2267.36, 2267.56, 2267.76, 2267.96, 2268.16, 2268.36, 2268.56, 2268.76, 2268.96, 2269.16, 2269.36, 2269.86, 2270.06, 2270.26, 2270.46, 2270.66, 2270.86, 2271.06, 2271.26, 2271.46, 2271.66, 2271.86, 2272.06, 2272.26, 2272.46, 2272.66, 2272.86, 2273.06, 2273.26, 2273.46, 2273.66, 2273.86, 2274.06, 2274.26, 2274.46], "yaxis": "y"}, {"line": {"color": "rgb(255, 127, 14)"}, "name": "Well GK", "showlegend": false, "type": "scatter", "x": [11.255, 11.734, 11.775, 11.075, 10.286, 9.404, 9.37, 9.522, 9.864, 10.216, 10.451 ...

# %% [markdown]
# As we can see, the the GR log of the core is now almost identical to the GR log of the well. Also note, that three last boring sequences were connected to each other to increase matching $R^{2}$.

# %% [markdown]
# ## Dataset matching

# %% [markdown]
# Usually, we want to match a group of wells (e.g. all wells from a field) instead of a single well. `PetroFlow` provides a simple way to do this in just several lines of code. First, we need to specify a path to the wells we want to match and create a dataset:

# %%
DATASET_PATH = "/path/to/a/dataset/*"
well_ds = WellDataset(path=DATASET_PATH, dirs=True, sort=True)

# %% [markdown]
# Matched wells will be saved in the `MATCHED_DATASET_PATH` directory:

# %%
MATCHED_DATASET_PATH = "/path/to/a/matched/dataset/"

# %% [markdown]
# Matching pipeline consists of 3 actions:
# * check, that well data is consistent
# * perform core-to-log matching with the given modes and save a matching report for each well
# * dump matched wells in the `MATCHED_DATASET_PATH` directory

# %%
matching_pipeline = (Pipeline()
    .check_regularity()
    .match_core_logs(mode=MATCHING_MODES, save_report=True)
    .dump(MATCHED_DATASET_PATH)
    .run(batch_size=1, n_epochs=1, shuffle=False, drop_last=False, bar=True, lazy=True)
)

# %% [markdown]
# Now we need to link the created dataset to the pipeline and run it:

# %%
(well_ds >> matching_pipeline).run()
# Out:
# 100%|██████████| 15/15 [01:18<00:00,  5.22s/it]

# %% [markdown]
# As a result, `MATCHED_DATASET_PATH` will contain directories with all matched wells.

# %% [markdown]
# ## Matching research

# %% [markdown]
# Sometimes we need to run a pipeline several times with different parameters. For example, we may want to smooth the logs with Gaussian filters of different sizes before performing core-to-log matching. To do this, we will use the `research` module. As in the previous case, first, we need to create a dataset of wells:

# %%
DATASET_PATH = "/path/to/a/dataset/*"
well_ds = WellDataset(path=DATASET_PATH, dirs=True, sort=True)

# %% [markdown]
# Then we specify parameters of our pipeline: a directory to save the results and a list of Gaussian kernel sizes:

# %%
MATCHED_DATASETS_PATH = "/path/to/a/matched/dataset/"
grid = Option("win_size", [None, 101, 201, 301])

# %% [markdown]
# Now we create a matching pipeline, that is almost identical to the one in the previous section except for several arguments, that it gets from the config of the `Research`:

# %%
matching_pipeline = (Pipeline()
    .check_regularity()
    .match_core_logs(mode=MATCHING_MODES, gaussian_win_size=C("win_size"))
    .dump(L(os.path.join)(MATCHED_DATASETS_PATH, C("win_size").str()))
    .run(batch_size=4, n_epochs=1, shuffle=False, drop_last=False, lazy=True)
)

# %% [markdown]
# Finally, we create a `Research` instance, specify the dataset, the pipeline and its parameters and run it:

# %%
research = (Research()
    .add_pipeline(matching_pipeline, dataset=well_ds, name="matching")
    .add_grid(grid)
)

research.run(name="matching_research", bar=True)
# Out:
# Research matching_research is starting...
# Distributor has 4 jobs
# 100%|██████████| 4/4 [05:32<00:00, 83.03s/it]

# %% [markdown]
# As a result, `MATCHED_DATASETS_PATH` will contain directories for each Gaussian kernel size with matched wells inside.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this notebook, we learned how to use `PetroFlow` to:
# * perform core-to-log matching for a single well
# * match the whole dataset of wells at once
# * run the matching pipeline several times with different parameters
