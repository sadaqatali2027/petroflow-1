# %%
import sys
sys.path.insert(0, "..")

from well_logs import Well

# %%
import os

# %%
PATH = "../../matched_dataset/"
WELLS = os.listdir(PATH)
WELL_NUM = 2

# %%
well = Well(PATH+WELLS[WELL_NUM])

# %%
well.segments[0].check_regularity()

# %%
well.segments[0].samples
# Out:
#                                         SAMPLE  QC
# DEPTH_FROM DEPTH_TO
# 2355.60    2356.58    417по_2355.6_2356.58.png   1
# 2356.58    2357.56   417по_2356.58_2357.56.png   1
# 2357.56    2358.59   417по_2357.56_2358.59.png   1
# 2358.59    2359.59   417по_2358.59_2359.59.png   1
# 2359.59    2360.60    417по_2359.59_2360.6.png   1
# ...                                        ...  ..
# 3153.95    3155.05   417по_3153.95_3155.05.png   1
# 3155.05    3156.15   417по_3155.05_3156.15.png   1
# 3156.15    3157.25   417по_3156.15_3157.25.png   1
# 3157.25    3157.40    417по_3157.25_3157.4.png   1
# 3157.40    3157.50     417по_3157.4_3157.5.png   1
#
# [161 rows x 2 columns]
